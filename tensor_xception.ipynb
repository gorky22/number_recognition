# %% [markdown]
# Here we will try to use technic Augmentation of data with combination of transfer learning

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

resolution = (256, 256)

#predprocess data 
directory = 'datasets'

train = image_dataset_from_directory(
    directory,
    labels = "inferred",
    label_mode = "int",
    class_names = None,
    color_mode = "rgb",
    batch_size = 32,
    image_size = resolution,
    seed = 100,
    crop_to_aspect_ratio = False,
    validation_split=0.1,
    subset="training",

)

valid = image_dataset_from_directory(
    directory,
    labels = "inferred",
    label_mode = "int",
    class_names = None,
    color_mode = "rgb",
    batch_size = 32,
    image_size = resolution,
    seed = 100,
    crop_to_aspect_ratio = False,
    validation_split=0.1,
    subset="validation",

)
# Out:
# Found 11302 files belonging to 8 classes.
# Using 10172 files for training.
# Found 11302 files belonging to 8 classes.
# Using 1130 files for validation.

# %%
# Prefetch images to memory, to make training faster

AUTOTUNE = tf.data.AUTOTUNE

train = train.prefetch(buffer_size=AUTOTUNE)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
  tf.keras.layers.experimental.preprocessing.RandomContrast(0.2),
  tf.keras.layers.experimental.preprocessing.RandomZoom(0.2),
])

# %%
# Create the base model from the pre-trained model MobileNet V2
IMG_SHAPE = resolution + (3,)
base_model = tf.keras.applications.Xception(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %%
# Keep the pre-trained weights, set this to true to retrain the whole model.
base_model.trainable = False

# %%
input_shape = tf.keras.Input(shape=(resolution[0],resolution[1], 3))
x = data_augmentation(input_shape)

## we want to get resolution of dataset imgs as was in pre-trained model
x =  tf.keras.applications.mobilenet_v2.preprocess_input(x)
x = base_model(x, training=False)

x = tf.keras.layers.GlobalAveragePooling2D()(x)

## preventing overfitiing
x = tf.keras.layers.Dropout(0.2)(x)

## this is layer is added because we want to our dataset classes == pretrained model outputs
outputs_shape = tf.keras.layers.Dense(8)(x)
model = tf.keras.Model(input_shape, outputs_shape)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(), # lr=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(train,
                    epochs=60,
                    validation_data=valid)
# Out:
# Epoch 1/60
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 318/318 [==============================] - 357s 1s/step - loss: 0.9890 - accuracy: 0.6668 - val_loss: 0.7445 - val_accuracy: 0.7487
# Epoch 2/60
# 318/318 [==============================] - 352s 1s/step - loss: 0.6571 - accuracy: 0.7925 - val_loss: 0.6115 - val_accuracy: 0.8088
# Epoch 3/60
# 318/318 [==============================] - 355s 1s/step - loss: 0.5414 - accuracy: 0.8349 - val_loss: 0.5127 - val_accuracy: 0.8522
# Epoch 4/60
# 318/318 [==============================] - 352s 1s/step - loss: 0.4837 - accuracy: 0.8565 - val_loss: 0.4644 - val_accuracy: 0.8690
# Epoch 5/60
# 318/318 [==============================] - 353s 1s/step - loss: 0.4340 - accuracy: 0.8751 - val_loss: 0.4296 - val_accuracy: 0.8903
# Epoch 6/60
# 318/318 [==============================] - 348s 1s/step - loss: 0.4060 - accuracy: 0.8806 - val_loss: 0.4044 - val_accuracy: 0.8929
# Epoch 7/60
# 318/318 [==============================] - 356s 1s/step - loss: 0.3892 - accuracy: 0.8847 - val_loss: 0.3835 - val_accuracy: 0.8982
# Epoch 8/60
# 318/318 [==============================] - 360s 1s/step - loss: 0.3682 - accuracy: 0.8950 - val_loss: 0.3547 - val_accuracy: 0.9035
# Epoch 9/60
# 318/318 [==============================] - 357s 1s/step - loss: 0.3520 - accuracy: 0.8980 - val_loss: 0.3508 - val_accuracy: 0.9088
# Epoch 10/60
# 318/318 [==============================] - 347s 1s/step - loss: 0.3352 - accuracy: 0.9006 - val_loss: 0.3232 - val_accuracy: 0.9150
# Epoch 11/60
# 318/318 [==============================] - 346s 1s/step - loss: 0.3306 - accuracy: 0.9043 - val_loss: 0.3144 - val_accuracy: 0.9195
# Epoch 12/60
# 318/318 [==============================] - 348s 1s/step - loss: 0.3273 - accuracy: 0.9026 - val_loss: 0.3067 - val_accuracy: 0.9159
# Epoch 13/60
# 318/318 [==============================] - 348s 1s/step - loss: 0.3076 - accuracy: 0.9076 - val_loss: 0.3004 - val_accuracy: 0.9248
# Epoch 14/60
# 318/318 [==============================] - 351s 1s/step - loss: 0.3074 - accuracy: 0.9091 - val_loss: 0.2964 - val_accuracy: 0.9221
# Epoch 15/60
# 318/318 [==============================] - 354s 1s/step - loss: 0.2997 - accuracy: 0.9100 - val_loss: 0.2881 - val_accuracy: 0.9274
# Epoch 16/60
# 318/318 [==============================] - 355s 1s/step - loss: 0.2957 - accuracy: 0.9096 - val_loss: 0.3013 - val_accuracy: 0.9159
# Epoch 17/60
# 318/318 [==============================] - 343s 1s/step - loss: 0.2977 - accuracy: 0.9095 - val_loss: 0.3001 - val_accuracy: 0.9204
# Epoch 18/60
# 318/318 [==============================] - 356s 1s/step - loss: 0.2837 - accuracy: 0.9142 - val_loss: 0.2892 - val_accuracy: 0.9239
# Epoch 19/60
# 318/318 [==============================] - 353s 1s/step - loss: 0.2797 - accuracy: 0.9191 - val_loss: 0.2764 - val_accuracy: 0.9248
# Epoch 20/60
# 318/318 [==============================] - 343s 1s/step - loss: 0.2804 - accuracy: 0.9209 - val_loss: 0.2894 - val_accuracy: 0.9239
# Epoch 21/60
# 318/318 [==============================] - 358s 1s/step - loss: 0.2775 - accuracy: 0.9164 - val_loss: 0.2814 - val_accuracy: 0.9257
# Epoch 22/60
# 318/318 [==============================] - 350s 1s/step - loss: 0.2714 - accuracy: 0.9207 - val_loss: 0.2652 - val_accuracy: 0.9274
# Epoch 23/60
# 318/318 [==============================] - 343s 1s/step - loss: 0.2646 - accuracy: 0.9197 - val_loss: 0.2649 - val_accuracy: 0.9363
# Epoch 24/60
# 318/318 [==============================] - 347s 1s/step - loss: 0.2598 - accuracy: 0.9219 - val_loss: 0.2620 - val_accuracy: 0.9354
# Epoch 25/60
# 318/318 [==============================] - 344s 1s/step - loss: 0.2646 - accuracy: 0.9165 - val_loss: 0.2638 - val_accuracy: 0.9336
# Epoch 26/60
# 318/318 [==============================] - 344s 1s/step - loss: 0.2638 - accuracy: 0.9231 - val_loss: 0.2714 - val_accuracy: 0.9283
# Epoch 27/60
# 318/318 [==============================] - 348s 1s/step - loss: 0.2584 - accuracy: 0.9194 - val_loss: 0.2651 - val_accuracy: 0.9336
# Epoch 28/60
# 318/318 [==============================] - 344s 1s/step - loss: 0.2611 - accuracy: 0.9219 - val_loss: 0.2540 - val_accuracy: 0.9327
# Epoch 29/60
# 318/318 [==============================] - 343s 1s/step - loss: 0.2601 - accuracy: 0.9207 - val_loss: 0.2553 - val_accuracy: 0.9381
# 318/318 [==============================] - 341s 1s/step - loss: 0.2333 - accuracy: 0.9275 - val_loss: 0.2441 - val_accuracy: 0.9336
# Epoch 50/60
# 318/318 [==============================] - 343s 1s/step - loss: 0.2350 - accuracy: 0.9269 - val_loss: 0.2534 - val_accuracy: 0.9372
# Epoch 51/60
# 318/318 [==============================] - 351s 1s/step - loss: 0.2311 - accuracy: 0.9280 - val_loss: 0.2555 - val_accuracy: 0.9345
# Epoch 52/60
# 318/318 [==============================] - 346s 1s/step - loss: 0.2400 - accuracy: 0.9234 - val_loss: 0.2508 - val_accuracy: 0.9336
# Epoch 53/60
# 318/318 [==============================] - 341s 1s/step - loss: 0.2212 - accuracy: 0.9315 - val_loss: 0.2438 - val_accuracy: 0.9416
# Epoch 54/60
# 318/318 [==============================] - 348s 1s/step - loss: 0.2318 - accuracy: 0.9267 - val_loss: 0.2399 - val_accuracy: 0.9434
# Epoch 55/60
# 318/318 [==============================] - 344s 1s/step - loss: 0.2336 - accuracy: 0.9264 - val_loss: 0.2585 - val_accuracy: 0.9327
# Epoch 56/60
# 318/318 [==============================] - 343s 1s/step - loss: 0.2272 - accuracy: 0.9276 - val_loss: 0.2358 - val_accuracy: 0.9381
# Epoch 57/60
# 318/318 [==============================] - 342s 1s/step - loss: 0.2273 - accuracy: 0.9288 - val_loss: 0.2415 - val_accuracy: 0.9345
# Epoch 58/60
# 318/318 [==============================] - 343s 1s/step - loss: 0.2380 - accuracy: 0.9232 - val_loss: 0.2532 - val_accuracy: 0.9372
# Epoch 59/60
# 318/318 [==============================] - 347s 1s/step - loss: 0.2300 - accuracy: 0.9298 - val_loss: 0.2503 - val_accuracy: 0.9372
# Epoch 60/60
# 318/318 [==============================] - 341s 1s/step - loss: 0.2412 - accuracy: 0.9236 - val_loss: 0.2485 - val_accuracy: 0.9345

# %%
model.save('model2.h5')

# %%
w = 10
h = 10
fig = plt.figure(figsize=(10, 5))

fig.add_subplot(1, 2, 1)
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.legend(loc='best')

fig.add_subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.legend(loc='best')
plt.show()

# %%
import os
from PIL import Image
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

def plot_img(img_matrix):
    fig = plt.figure()
    ax1 = fig.add_subplot(121)
    
    ax1.imshow(img_matrix.astype('uint8'))

    plt.show()

def get_result(prediction):
    return np.argmax(prediction)

def procces_img(path):
    img_tmp = Image.open(path).resize((resolution[0],resolution[1]))
    return np.array(img_tmp).astype('uint8')




img = procces_img('test/Screenshot 2023-01-17 113435.jpg')
plot_img(img)
prediction = model.predict(img.reshape((-1, 256, 256, 3)))
print(f'{get_result(prediction)} predicted' )
prediction
# Out:
# 1/1 [==============================] - 0s 466ms/step
# 7 predicted
# array([[ -7.291543  ,  -2.7108462 ,  -4.531022  , -11.252198  ,
#          -2.0314147 ,  -4.579196  ,  -9.438374  ,   0.43057746]],
#       dtype=float32)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  sequential_1 (Sequential)   (None, 256, 256, 3)       0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 256, 256, 3)      0
#  da)
#
#  tf.math.subtract_1 (TFOpLam  (None, 256, 256, 3)      0
#  bda)
#
#  xception (Functional)       (None, 8, 8, 2048)        20861480
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 8)                 16392
#
# =================================================================
# Total params: 20,877,872
# Trainable params: 16,392
# Non-trainable params: 20,861,480
# _________________________________________________________________
