# %% [markdown]
# Here we will try to use technic Augmentation of data with combination of transfer learning

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

resolution = (256, 256)

#predprocess data 
directory = 'datasets2'

train = image_dataset_from_directory(
    directory,
    labels = "inferred",
    label_mode = "int",
    class_names = None,
    color_mode = "rgb",
    batch_size = 32,
    image_size = resolution,
    seed = 100,
    crop_to_aspect_ratio = False,
    validation_split=0.1,
    subset="training",

)

valid = image_dataset_from_directory(
    directory,
    labels = "inferred",
    label_mode = "int",
    class_names = None,
    color_mode = "rgb",
    batch_size = 32,
    image_size = resolution,
    seed = 100,
    crop_to_aspect_ratio = False,
    validation_split=0.1,
    subset="validation",

)
# Out:
# Found 685 files belonging to 8 classes.
# Using 617 files for training.
# Found 685 files belonging to 8 classes.
# Using 68 files for validation.

# %%
# Prefetch images to memory, to make training faster

AUTOTUNE = tf.data.AUTOTUNE

train = train.prefetch(buffer_size=AUTOTUNE)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
  tf.keras.layers.experimental.preprocessing.RandomContrast(0.2),
  tf.keras.layers.experimental.preprocessing.RandomZoom(0.2),
])

# %%
# Create the base model from the pre-trained model MobileNet V2
IMG_SHAPE = resolution + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
# Keep the pre-trained weights, set this to true to retrain the whole model.
base_model.trainable = False

# %%
input_shape = tf.keras.Input(shape=(resolution[0],resolution[1], 3))
x = data_augmentation(input_shape)

## we want to get resolution of dataset imgs as was in pre-trained model
x =  tf.keras.applications.mobilenet_v2.preprocess_input(x)
x = base_model(x, training=False)

x = tf.keras.layers.GlobalAveragePooling2D()(x)

## preventing overfitiing
x = tf.keras.layers.Dropout(0.2)(x)

## this is layer is added because we want to our dataset classes == pretrained model outputs
outputs_shape = tf.keras.layers.Dense(8)(x)
model = tf.keras.Model(input_shape, outputs_shape)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(), # lr=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(train,
                    epochs=60,
                    validation_data=valid)
# Out:
# Epoch 1/60
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 20/20 [==============================] - 17s 689ms/step - loss: 2.1484 - accuracy: 0.2253 - val_loss: 1.6822 - val_accuracy: 0.3676
# Epoch 2/60
# 20/20 [==============================] - 13s 676ms/step - loss: 1.6585 - accuracy: 0.4003 - val_loss: 1.4313 - val_accuracy: 0.5441
# Epoch 3/60
# 20/20 [==============================] - 14s 678ms/step - loss: 1.4808 - accuracy: 0.4441 - val_loss: 1.3733 - val_accuracy: 0.5882
# Epoch 4/60
# 20/20 [==============================] - 14s 672ms/step - loss: 1.3269 - accuracy: 0.5186 - val_loss: 1.3339 - val_accuracy: 0.5735
# Epoch 5/60
# 20/20 [==============================] - 14s 700ms/step - loss: 1.2120 - accuracy: 0.5721 - val_loss: 1.2665 - val_accuracy: 0.6029
# Epoch 6/60
# 20/20 [==============================] - 13s 672ms/step - loss: 1.1772 - accuracy: 0.5835 - val_loss: 1.2615 - val_accuracy: 0.6324
# Epoch 7/60
# 20/20 [==============================] - 13s 663ms/step - loss: 1.1280 - accuracy: 0.6013 - val_loss: 1.2490 - val_accuracy: 0.6176
# Epoch 8/60
# 20/20 [==============================] - 13s 664ms/step - loss: 1.1227 - accuracy: 0.6029 - val_loss: 1.2526 - val_accuracy: 0.6324
# Epoch 9/60
# 20/20 [==============================] - 13s 666ms/step - loss: 1.0188 - accuracy: 0.6370 - val_loss: 1.2187 - val_accuracy: 0.6176
# Epoch 10/60
# 20/20 [==============================] - 13s 646ms/step - loss: 0.9564 - accuracy: 0.6759 - val_loss: 1.2043 - val_accuracy: 0.6471
# Epoch 11/60
# 20/20 [==============================] - 13s 643ms/step - loss: 0.9681 - accuracy: 0.6207 - val_loss: 1.1720 - val_accuracy: 0.6176
# Epoch 12/60
# 20/20 [==============================] - 13s 667ms/step - loss: 0.9209 - accuracy: 0.6726 - val_loss: 1.2044 - val_accuracy: 0.6471
# Epoch 13/60
# 20/20 [==============================] - 14s 702ms/step - loss: 0.9208 - accuracy: 0.6742 - val_loss: 1.1521 - val_accuracy: 0.6176
# Epoch 14/60
# 20/20 [==============================] - 14s 700ms/step - loss: 0.8640 - accuracy: 0.7018 - val_loss: 1.1885 - val_accuracy: 0.6324
# Epoch 15/60
# 20/20 [==============================] - 13s 671ms/step - loss: 0.8670 - accuracy: 0.7018 - val_loss: 1.1838 - val_accuracy: 0.6471
# Epoch 16/60
# 20/20 [==============================] - 13s 671ms/step - loss: 0.8490 - accuracy: 0.7050 - val_loss: 1.1448 - val_accuracy: 0.6324
# Epoch 17/60
# 20/20 [==============================] - 14s 685ms/step - loss: 0.8152 - accuracy: 0.7245 - val_loss: 1.1231 - val_accuracy: 0.6324
# Epoch 18/60
# 20/20 [==============================] - 13s 664ms/step - loss: 0.8036 - accuracy: 0.7212 - val_loss: 1.1257 - val_accuracy: 0.6471
# Epoch 19/60
# 20/20 [==============================] - 13s 649ms/step - loss: 0.7833 - accuracy: 0.7245 - val_loss: 1.1617 - val_accuracy: 0.6471
# Epoch 20/60
# 20/20 [==============================] - 12s 624ms/step - loss: 0.7651 - accuracy: 0.7455 - val_loss: 1.1516 - val_accuracy: 0.6324
# Epoch 21/60
# 20/20 [==============================] - 13s 651ms/step - loss: 0.7456 - accuracy: 0.7293 - val_loss: 1.1639 - val_accuracy: 0.6765
# Epoch 22/60
# 20/20 [==============================] - 12s 610ms/step - loss: 0.7155 - accuracy: 0.7585 - val_loss: 1.1226 - val_accuracy: 0.6912
# Epoch 23/60
# 20/20 [==============================] - 13s 645ms/step - loss: 0.7242 - accuracy: 0.7682 - val_loss: 1.1415 - val_accuracy: 0.6618
# Epoch 24/60
# 20/20 [==============================] - 11s 530ms/step - loss: 0.6860 - accuracy: 0.7731 - val_loss: 1.1322 - val_accuracy: 0.6471
# Epoch 25/60
# 20/20 [==============================] - 11s 538ms/step - loss: 0.6953 - accuracy: 0.7731 - val_loss: 1.1498 - val_accuracy: 0.6765
# Epoch 26/60
# 20/20 [==============================] - 11s 535ms/step - loss: 0.6863 - accuracy: 0.7699 - val_loss: 1.1455 - val_accuracy: 0.6765
# Epoch 27/60
# 20/20 [==============================] - 10s 520ms/step - loss: 0.6299 - accuracy: 0.8006 - val_loss: 1.1207 - val_accuracy: 0.6618
# Epoch 28/60
# 20/20 [==============================] - 10s 519ms/step - loss: 0.6825 - accuracy: 0.7715 - val_loss: 1.1314 - val_accuracy: 0.6912
# Epoch 29/60
# 20/20 [==============================] - 11s 528ms/step - loss: 0.6751 - accuracy: 0.7731 - val_loss: 1.1348 - val_accuracy: 0.6618
# Epoch 30/60
# 20/20 [==============================] - 11s 537ms/step - loss: 0.6315 - accuracy: 0.7796 - val_loss: 1.1369 - val_accuracy: 0.6618
# Epoch 31/60
# 20/20 [==============================] - 11s 555ms/step - loss: 0.5959 - accuracy: 0.8006 - val_loss: 1.1685 - val_accuracy: 0.6471
# Epoch 32/60
# 20/20 [==============================] - 12s 581ms/step - loss: 0.6101 - accuracy: 0.7893 - val_loss: 1.1943 - val_accuracy: 0.6618
# Epoch 33/60
# 20/20 [==============================] - 12s 586ms/step - loss: 0.6243 - accuracy: 0.7925 - val_loss: 1.1777 - val_accuracy: 0.6765
# Epoch 34/60
# 20/20 [==============================] - 11s 549ms/step - loss: 0.5728 - accuracy: 0.8071 - val_loss: 1.1712 - val_accuracy: 0.6912
# Epoch 35/60
# 20/20 [==============================] - 11s 573ms/step - loss: 0.5973 - accuracy: 0.7715 - val_loss: 1.1870 - val_accuracy: 0.6765
# Epoch 36/60
# 20/20 [==============================] - 11s 548ms/step - loss: 0.5978 - accuracy: 0.7958 - val_loss: 1.1576 - val_accuracy: 0.6765
# Epoch 37/60
# 20/20 [==============================] - 11s 578ms/step - loss: 0.5620 - accuracy: 0.8282 - val_loss: 1.1349 - val_accuracy: 0.6618
# Epoch 38/60
# 20/20 [==============================] - 11s 574ms/step - loss: 0.5604 - accuracy: 0.8152 - val_loss: 1.1526 - val_accuracy: 0.6618
# Epoch 39/60
# 20/20 [==============================] - 11s 556ms/step - loss: 0.5691 - accuracy: 0.7942 - val_loss: 1.1574 - val_accuracy: 0.7059
# Epoch 40/60
# 20/20 [==============================] - 11s 546ms/step - loss: 0.5402 - accuracy: 0.8266 - val_loss: 1.2018 - val_accuracy: 0.6765
# Epoch 41/60
# 20/20 [==============================] - 12s 583ms/step - loss: 0.5543 - accuracy: 0.7990 - val_loss: 1.1798 - val_accuracy: 0.7059
# Epoch 42/60
# 20/20 [==============================] - 12s 577ms/step - loss: 0.5635 - accuracy: 0.8071 - val_loss: 1.1651 - val_accuracy: 0.6912
# Epoch 43/60
# 20/20 [==============================] - 11s 542ms/step - loss: 0.5308 - accuracy: 0.8347 - val_loss: 1.1796 - val_accuracy: 0.6765
# Epoch 44/60
# 20/20 [==============================] - 11s 523ms/step - loss: 0.4974 - accuracy: 0.8395 - val_loss: 1.1792 - val_accuracy: 0.6912
# Epoch 45/60
# 20/20 [==============================] - 11s 569ms/step - loss: 0.5239 - accuracy: 0.8233 - val_loss: 1.1997 - val_accuracy: 0.6912
# Epoch 46/60
# 20/20 [==============================] - 11s 565ms/step - loss: 0.5042 - accuracy: 0.8314 - val_loss: 1.1896 - val_accuracy: 0.6618
# Epoch 47/60
# 20/20 [==============================] - 12s 604ms/step - loss: 0.5165 - accuracy: 0.8460 - val_loss: 1.1973 - val_accuracy: 0.7059
# Epoch 48/60
# 20/20 [==============================] - 11s 568ms/step - loss: 0.4915 - accuracy: 0.8428 - val_loss: 1.1617 - val_accuracy: 0.6765
# Epoch 49/60
# 20/20 [==============================] - 12s 586ms/step - loss: 0.5403 - accuracy: 0.8039 - val_loss: 1.2015 - val_accuracy: 0.6912
# Epoch 50/60
# 20/20 [==============================] - 11s 566ms/step - loss: 0.5054 - accuracy: 0.8347 - val_loss: 1.1950 - val_accuracy: 0.6765
# Epoch 51/60
# 20/20 [==============================] - 12s 588ms/step - loss: 0.5200 - accuracy: 0.8169 - val_loss: 1.1841 - val_accuracy: 0.6618
# Epoch 52/60
# 20/20 [==============================] - 12s 607ms/step - loss: 0.5161 - accuracy: 0.8347 - val_loss: 1.2148 - val_accuracy: 0.6618
# Epoch 53/60
# 20/20 [==============================] - 11s 543ms/step - loss: 0.4805 - accuracy: 0.8395 - val_loss: 1.2084 - val_accuracy: 0.6912
# Epoch 54/60
# 20/20 [==============================] - 12s 580ms/step - loss: 0.4934 - accuracy: 0.8314 - val_loss: 1.1807 - val_accuracy: 0.6912
# Epoch 55/60
# 20/20 [==============================] - 12s 584ms/step - loss: 0.4722 - accuracy: 0.8525 - val_loss: 1.1769 - val_accuracy: 0.6618
# Epoch 56/60
# 20/20 [==============================] - 11s 550ms/step - loss: 0.5078 - accuracy: 0.8136 - val_loss: 1.1483 - val_accuracy: 0.7353
# Epoch 57/60
# 20/20 [==============================] - 12s 587ms/step - loss: 0.4635 - accuracy: 0.8606 - val_loss: 1.2084 - val_accuracy: 0.6912
# Epoch 58/60
# 20/20 [==============================] - 10s 519ms/step - loss: 0.4833 - accuracy: 0.8558 - val_loss: 1.1989 - val_accuracy: 0.7059
# Epoch 59/60
# 20/20 [==============================] - 10s 517ms/step - loss: 0.4720 - accuracy: 0.8395 - val_loss: 1.1908 - val_accuracy: 0.6912
# Epoch 60/60
# 20/20 [==============================] - 11s 530ms/step - loss: 0.4572 - accuracy: 0.8412 - val_loss: 1.2185 - val_accuracy: 0.7059

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.legend(loc='best')

plt.figure()
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.legend(loc='best')
plt.show()

# %%
import os
from PIL import Image
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

def plot_img(img_matrix):
    fig = plt.figure()
    ax1 = fig.add_subplot(121)
    
    ax1.imshow(img_matrix.astype('uint8'))

    plt.show()

def get_result(prediction):
    return np.argmax(prediction)

def procces_img(path):
    img_tmp = Image.open(path).resize((resolution[0],resolution[1]))
    return np.array(img_tmp).astype('uint8')




img = procces_img('test/6_1.jpg')
plot_img(img)
prediction = model.predict(img.reshape((-1, 256, 256, 3)))
print(f'{get_result(prediction)} predicted' )
prediction
# Out:
# 1/1 [==============================] - 0s 34ms/step
# 2 predicted
# array([[-6.3203454 , -4.263617  , -0.01285034, -6.8743496 , -0.73443323,
#         -1.1293774 , -5.205034  , -5.664991  ]], dtype=float32)
